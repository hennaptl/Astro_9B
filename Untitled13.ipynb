# %%
import json
import matplotlib.pyplot as plt

# %%
with open('par-lick.json') as f:
    data = json.load(f)

z = data['profrest']['zgrid']   # altitude

# %%
import pandas as pd

df = pd.read_csv('testdata.prof', sep=None, engine='python')
print(df.head())
# Out:
#                                                                # Date   Star  \
# 2025-10-05-03:04:37 424 53.11 155148.852756 0.207 0.622 0.305   17.69  4.277
# 2025-10-05-03:05:31 424 53.11 152915.276400 0.238 0.706 0.298   18.20  4.257
#
#                                                                  Zen   Flux  \
# 2025-10-05-03:04:37 424 53.11 155148.852756 0.207 0.622 0.305  1.856  0.101
# 2025-10-05-03:05:31 424 53.11 152915.276400 0.238 0.706 0.298  1.811  0.115
#
#                                                                 See2   See  \
# 2025-10-05-03:04:37 424 53.11 155148.852756 0.207 0.622 0.305  0.419  2.15
# 2025-10-05-03:05:31 424 53.11 152915.276400 0.238 0.706 0.298  0.443  2.91
#
#                                                                Fsee  Wind  \
# 2025-10-05-03:04:37 424 53.11 155148.852756 0.207 0.622 0.305   0.0   0.0
# 2025-10-05-03:05:31 424 53.11 152915.276400 0.238 0.706 0.298   0.0   0.0
#
# ...

# %%
plt.plot(prof, z)
plt.xlabel('Turbulence Strength')
plt.ylabel('Altitude (m)')
plt.title('Altitude vs Turbulence Strength')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.plot(prof, z)
#       2 plt.xlabel('Turbulence Strength')
#       3 plt.ylabel('Altitude (m)')
#
# NameError: name 'prof' is not defined
